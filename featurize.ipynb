# %% [markdown]
# # Featurization

# %%
# get the data from the file
import pandas as pd

data = pd.read_csv('./data/cleaned_data_without_outliers.csv')

# %%
data.head()
# Out:
#   material_id formula_pretty     composition  crystal_system  space_group  \
# 0    mp-28967      Ba(PdS2)2      Ba2 Pd4 S8               4           11
# 1   mp-766094          NbO2F       Nb4 O8 F4               3           19
# 2    mp-36577      Sr(AsS2)2      Sr1 As2 S4               5            1
# 3  mp-1102092     NaFe(SO4)2  Na4 Fe4 S8 O32               4           12
# 4   mp-720391         BH4NF4   B4 H16 N4 F16               3           62
#
#   point_group  band_gap      volume   density  density_atomic  \
# 0         2/m    0.7792  316.341404  5.022717       22.595815
# 1         222    2.8980  253.915299  3.764366       15.869706
# 2           1    1.7212  196.220495  3.094976       28.031499
# 3          -1    2.0944  620.336826  2.901260       12.923684
# 4         mmm    7.4812  374.200384  1.860992        9.355010
#
#    formation_energy_per_atom    e_total    e_ionic  e_electronic
# 0                  -1.124079  17.048334   7.118969      9.929365
# 1                  -3.099174  17.572010  13.469477      4.102533
# 2                  -0.766100  18.488667  12.443616      6.045051
# 3                  -1.948264   9.596025   6.499905      3.096120
# 4                  -1.970766   6.216546   4.350314      1.866232

# %%
data.shape
# Out:
# (7262, 14)

# %%
# Change the name of composition column
data.rename(columns={'composition': 'composition_str'}, inplace=True)

# %%
# turn the composition column from str to composition
from matminer.featurizers.conversions import StrToComposition

stc = StrToComposition(target_col_id='composition')
data = stc.featurize_dataframe(data, col_id="composition_str", pbar=True)
# Out:
# StrToComposition:   0%|          | 0/7262 [00:00<?, ?it/s]

# %%
data.head()
# Out:
#   material_id formula_pretty composition_str  crystal_system  space_group  \
# 0    mp-28967      Ba(PdS2)2      Ba2 Pd4 S8               4           11
# 1   mp-766094          NbO2F       Nb4 O8 F4               3           19
# 2    mp-36577      Sr(AsS2)2      Sr1 As2 S4               5            1
# 3  mp-1102092     NaFe(SO4)2  Na4 Fe4 S8 O32               4           12
# 4   mp-720391         BH4NF4   B4 H16 N4 F16               3           62
#
#   point_group  band_gap      volume   density  density_atomic  \
# 0         2/m    0.7792  316.341404  5.022717       22.595815
# 1         222    2.8980  253.915299  3.764366       15.869706
# 2           1    1.7212  196.220495  3.094976       28.031499
# 3          -1    2.0944  620.336826  2.901260       12.923684
# 4         mmm    7.4812  374.200384  1.860992        9.355010
#
#    formation_energy_per_atom    e_total    e_ionic  e_electronic  \
# 0                  -1.124079  17.048334   7.118969      9.929365
# 1                  -3.099174  17.572010  13.469477      4.102533
# 2                  -0.766100  18.488667  12.443616      6.045051
# 3                  -1.948264   9.596025   6.499905      3.096120
# 4                  -1.970766   6.216546   4.350314      1.866232
#
#       composition
# 0     (Ba, Pd, S)
# 1      (Nb, O, F)
# 2     (Sr, As, S)
# 3  (Na, Fe, S, O)
# 4    (B, H, N, F)

# %%
str(data.iloc[0, -1])
# Out:
# 'Ba2 Pd4 S8'

# %%
# 1. Composition-based features
from matminer.featurizers.composition import ElementProperty
featurizer = ElementProperty.from_preset('magpie') 	# extracting features from a predefined database
data_featurized = featurizer.featurize_dataframe(data, col_id='composition')
# Out:
# ElementProperty:   0%|          | 0/7262 [00:00<?, ?it/s]

# %%
data_featurized.head()
# Out:
#   material_id formula_pretty composition_str  crystal_system  space_group  \
# 0    mp-28967      Ba(PdS2)2      Ba2 Pd4 S8               4           11
# 1   mp-766094          NbO2F       Nb4 O8 F4               3           19
# 2    mp-36577      Sr(AsS2)2      Sr1 As2 S4               5            1
# 3  mp-1102092     NaFe(SO4)2  Na4 Fe4 S8 O32               4           12
# 4   mp-720391         BH4NF4   B4 H16 N4 F16               3           62
#
#   point_group  band_gap      volume   density  density_atomic  ...  \
# 0         2/m    0.7792  316.341404  5.022717       22.595815  ...
# 1         222    2.8980  253.915299  3.764366       15.869706  ...
# 2           1    1.7212  196.220495  3.094976       28.031499  ...
# 3          -1    2.0944  620.336826  2.901260       12.923684  ...
# 4         mmm    7.4812  374.200384  1.860992        9.355010  ...
#
#    MagpieData range GSmagmom  MagpieData mean GSmagmom  \
# 0                   0.000000                  0.000000
# 1                   0.000000                  0.000000
# 2                   0.000000                  0.000000
# 3                   2.110663                  0.175889
# 4                   0.000000                  0.000000
#
#    MagpieData avg_dev GSmagmom  MagpieData mode GSmagmom  \
# 0                     0.000000                       0.0
# 1                     0.000000                       0.0
# 2                     0.000000                       0.0
# 3                     0.322462                       0.0
# 4                     0.000000                       0.0
#
#   MagpieData minimum SpaceGroupNumber  MagpieData maximum SpaceGroupNumber  \
# 0                                70.0                                229.0
# 1                                12.0                                229.0
# 2                                70.0                                225.0
# 3                                12.0                                229.0
# 4                                15.0                                194.0
#
#    MagpieData range SpaceGroupNumber  MagpieData mean SpaceGroupNumber  \
# 0                              159.0                        137.000000
# 1                              217.0                         67.000000
# 2                              155.0                        119.571429
# 3                              217.0                         57.833333
# 4                              179.0                        119.600000
#
#    MagpieData avg_dev SpaceGroupNumber  MagpieData mode SpaceGroupNumber
# 0                            76.571429                              70.0
# 1                            81.000000                              12.0
# 2                            56.653061                              70.0
# 3                            61.111111                              12.0
# 4                            83.680000                              15.0
#
# [5 rows x 147 columns]

# %% [markdown]
# #### The features based on physical knowledge:
# - Atomic type --- composition
# - Crystal structure --- symmetry=SymmetryData(crystal_system=<CrystalSystem.trig: 'Trigonal'>, symbol='P3_121', number=152, point_group='32', symprec=0.1, version='1.16.5'),
# - band_gap
# - Atomic density per unit volume, ionic pair density per unit volume
#       --- density + density_atomic + volumn
# - Electronic polarization rate$\alpha_e$
#   - Electronic cloud radius$r_0$ --- 'MagpieData minimum CovalentRadius', 'MagpieData maximum CovalentRadius', 'MagpieData range CovalentRadius','MagpieData mean CovalentRadius',
#   - The number of electron --- 'MagpieData minimum Number', 'MagpieData maximum Number', 'MagpieData range Number', 'MagpieData mean Number',
# - Covalent electron polarization
#   - electronegativity --- 'MagpieData minimum Electronegativity', 'MagpieData maximum Electronegativity', 'MagpieData range Electronegativity', 'MagpieData mean Electronegativity'
#   - The number of electron

# %%
domain_features = ['crystal_system', 'space_group', 'band_gap', 'volume', 'density', 'density_atomic', 
                'formation_energy_per_atom']

domain_features += ['MagpieData minimum Number', 'MagpieData maximum Number', 'MagpieData range Number', 'MagpieData mean Number',
                 'MagpieData minimum CovalentRadius', 'MagpieData maximum CovalentRadius', 'MagpieData range CovalentRadius', 'MagpieData mean CovalentRadius',
                 'MagpieData minimum Electronegativity', 'MagpieData maximum Electronegativity', 'MagpieData range Electronegativity', 'MagpieData mean Electronegativity'
                 ]
domain_features
# Out:
# ['crystal_system',
#  'space_group',
#  'band_gap',
#  'volume',
#  'density',
#  'density_atomic',
#  'formation_energy_per_atom',
#  'MagpieData minimum Number',
#  'MagpieData maximum Number',
#  'MagpieData range Number',
#  'MagpieData mean Number',
#  'MagpieData minimum CovalentRadius',
#  'MagpieData maximum CovalentRadius',
#  'MagpieData range CovalentRadius',
#  'MagpieData mean CovalentRadius',
#  'MagpieData minimum Electronegativity',
#  'MagpieData maximum Electronegativity',
#  'MagpieData range Electronegativity',
#  'MagpieData mean Electronegativity']

# %%
domain_data = data_featurized[domain_features + ['e_electronic', 'e_ionic', 'e_total']]

# %%
domain_data.head()
# Out:
#    crystal_system  space_group  band_gap      volume   density  \
# 0               4           11    0.7792  316.341404  5.022717
# 1               3           19    2.8980  253.915299  3.764366
# 2               5            1    1.7212  196.220495  3.094976
# 3               4           12    2.0944  620.336826  2.901260
# 4               3           62    7.4812  374.200384  1.860992
#
#    density_atomic  formation_energy_per_atom  MagpieData minimum Number  \
# 0       22.595815                  -1.124079                       16.0
# 1       15.869706                  -3.099174                        8.0
# 2       28.031499                  -0.766100                       16.0
# 3       12.923684                  -1.948264                        8.0
# 4        9.355010                  -1.970766                        1.0
#
#    MagpieData maximum Number  MagpieData range Number  ...  \
# 0                       56.0                     40.0  ...
# 1                       41.0                     33.0  ...
# 2                       38.0                     22.0  ...
# 3                       26.0                     18.0  ...
# 4                        9.0                      8.0  ...
#
#    MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 0                              215.0                            110.0
# 1                              164.0                            107.0
# 2                              195.0                             90.0
# 3                              166.0                            100.0
# 4                               84.0                             53.0
#
#    MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 0                      130.428571                                  0.89
# 1                       88.250000                                  1.60
# 2                      121.857143                                  0.95
# 3                       86.333333                                  0.93
# 4                       50.700000                                  2.04
#
#    MagpieData maximum Electronegativity  MagpieData range Electronegativity  \
# 0                                  2.58                                1.69
# 1                                  3.98                                2.38
# 2                                  2.58                                1.63
# 3                                  3.44                                2.51
# 4                                  3.98                                1.94
#
#    MagpieData mean Electronegativity  e_electronic    e_ionic    e_total
# 0                           2.230000      9.929365   7.118969  17.048334
# 1                           3.115000      4.102533  13.469477  17.572010
# 2                           2.232857      6.045051  12.443616  18.488667
# 3                           2.953333      3.096120   6.499905   9.596025
# 4                           2.980000      1.866232   4.350314   6.216546
#
# [5 rows x 22 columns]

# %%
composition_features = data_featurized.columns[15:]
composition_features
# Out:
# Index(['MagpieData minimum Number', 'MagpieData maximum Number',
#        'MagpieData range Number', 'MagpieData mean Number',
#        'MagpieData avg_dev Number', 'MagpieData mode Number',
#        'MagpieData minimum MendeleevNumber',
#        'MagpieData maximum MendeleevNumber',
#        'MagpieData range MendeleevNumber', 'MagpieData mean MendeleevNumber',
#        ...
#        'MagpieData range GSmagmom', 'MagpieData mean GSmagmom',
#        'MagpieData avg_dev GSmagmom', 'MagpieData mode GSmagmom',
#        'MagpieData minimum SpaceGroupNumber',
#        'MagpieData maximum SpaceGroupNumber',
#        'MagpieData range SpaceGroupNumber', 'MagpieData mean SpaceGroupNumber',
#        'MagpieData avg_dev SpaceGroupNumber',
#        'MagpieData mode SpaceGroupNumber'],
#       dtype='object', length=132)

# %%
composition_data = data_featurized[list(composition_features) + ['e_electronic', 'e_ionic', 'e_total']]

# %%
composition_data.head()
# Out:
#    MagpieData minimum Number  MagpieData maximum Number  \
# 0                       16.0                       56.0
# 1                        8.0                       41.0
# 2                       16.0                       38.0
# 3                        8.0                       26.0
# 4                        1.0                        9.0
#
#    MagpieData range Number  MagpieData mean Number  MagpieData avg_dev Number  \
# 0                     40.0               30.285714                  16.326531
# 1                     33.0               16.500000                  12.250000
# 2                     22.0               24.000000                   9.142857
# 3                     18.0               11.083333                   4.125000
# 4                      8.0                5.200000                   3.400000
#
#    MagpieData mode Number  MagpieData minimum MendeleevNumber  \
# 0                    16.0                                 9.0
# 1                     8.0                                47.0
# 2                    16.0                                 8.0
# 3                     8.0                                 2.0
# 4                     1.0                                72.0
#
#    MagpieData maximum MendeleevNumber  MagpieData range MendeleevNumber  \
# 0                                88.0                              79.0
# 1                                93.0                              46.0
# 2                                88.0                              80.0
# 3                                88.0                              86.0
# 4                                93.0                              21.0
#
#    MagpieData mean MendeleevNumber  ...  MagpieData mode GSmagmom  \
# 0                        69.285714  ...                       0.0
# 1                        78.500000  ...                       0.0
# 2                        75.428571  ...                       0.0
# 3                        77.416667  ...                       0.0
# 4                        89.400000  ...                       0.0
#
#    MagpieData minimum SpaceGroupNumber  MagpieData maximum SpaceGroupNumber  \
# 0                                 70.0                                229.0
# 1                                 12.0                                229.0
# 2                                 70.0                                225.0
# 3                                 12.0                                229.0
# 4                                 15.0                                194.0
#
#    MagpieData range SpaceGroupNumber  MagpieData mean SpaceGroupNumber  \
# 0                              159.0                        137.000000
# 1                              217.0                         67.000000
# 2                              155.0                        119.571429
# 3                              217.0                         57.833333
# 4                              179.0                        119.600000
#
#    MagpieData avg_dev SpaceGroupNumber  MagpieData mode SpaceGroupNumber  \
# 0                            76.571429                              70.0
# 1                            81.000000                              12.0
# 2                            56.653061                              70.0
# 3                            61.111111                              12.0
# 4                            83.680000                              15.0
#
#    e_electronic    e_ionic    e_total
# 0      9.929365   7.118969  17.048334
# 1      4.102533  13.469477  17.572010
# 2      6.045051  12.443616  18.488667
# 3      3.096120   6.499905   9.596025
# 4      1.866232   4.350314   6.216546
#
# [5 rows x 135 columns]

# %%
# save data to csv
domain_data.to_csv('./data/domain_based_data.csv', index=False)
composition_data.to_csv('./data/composition_based_data.csv', index=False)
