# %% [markdown]
# # Using physics-based features to train the e_ionic model for prediction

# %% [markdown]
# - Get Data from csv file

# %%
# import the necessary libraries
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
from sklearn.linear_model import LinearRegression

# %%
# some global variables
TEST_SIZE = 0.30
RANDOM_STATE = 42
N_SPLITS = 10
# The depth of the decision tree
BEST_DEPTH = None

FIG_PATH = '../figures/domain_based/unClustered/e_ionic/'

# %%
data = pd.read_csv('../data/domain_based_data.csv')

# %%
data.head()
# Out:
#    crystal_system  space_group  band_gap      volume   density  \
# 0               4           11    0.7792  316.341404  5.022717
# 1               3           19    2.8980  253.915299  3.764366
# 2               5            1    1.7212  196.220495  3.094976
# 3               4           12    2.0944  620.336826  2.901260
# 4               3           62    7.4812  374.200384  1.860992
#
#    density_atomic  formation_energy_per_atom  MagpieData minimum Number  \
# 0       22.595815                  -1.124079                       16.0
# 1       15.869706                  -3.099174                        8.0
# 2       28.031499                  -0.766100                       16.0
# 3       12.923684                  -1.948264                        8.0
# 4        9.355010                  -1.970766                        1.0
#
#    MagpieData maximum Number  MagpieData range Number  ...  \
# 0                       56.0                     40.0  ...
# 1                       41.0                     33.0  ...
# 2                       38.0                     22.0  ...
# 3                       26.0                     18.0  ...
# 4                        9.0                      8.0  ...
#
#    MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 0                              215.0                            110.0
# 1                              164.0                            107.0
# 2                              195.0                             90.0
# 3                              166.0                            100.0
# 4                               84.0                             53.0
#
#    MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 0                      130.428571                                  0.89
# 1                       88.250000                                  1.60
# 2                      121.857143                                  0.95
# 3                       86.333333                                  0.93
# 4                       50.700000                                  2.04
#
#    MagpieData maximum Electronegativity  MagpieData range Electronegativity  \
# 0                                  2.58                                1.69
# 1                                  3.98                                2.38
# 2                                  2.58                                1.63
# 3                                  3.44                                2.51
# 4                                  3.98                                1.94
#
#    MagpieData mean Electronegativity  e_electronic    e_ionic    e_total
# 0                           2.230000      9.929365   7.118969  17.048334
# 1                           3.115000      4.102533  13.469477  17.572010
# 2                           2.232857      6.045051  12.443616  18.488667
# 3                           2.953333      3.096120   6.499905   9.596025
# 4                           2.980000      1.866232   4.350314   6.216546
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7262 entries, 0 to 7261
# Data columns (total 22 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   crystal_system                        7262 non-null   int64
#  1   space_group                           7262 non-null   int64
#  2   band_gap                              7262 non-null   float64
#  3   volume                                7262 non-null   float64
#  4   density                               7262 non-null   float64
#  5   density_atomic                        7262 non-null   float64
#  6   formation_energy_per_atom             7262 non-null   float64
#  7   MagpieData minimum Number             7262 non-null   float64
#  8   MagpieData maximum Number             7262 non-null   float64
#  9   MagpieData range Number               7262 non-null   float64
#  10  MagpieData mean Number                7262 non-null   float64
#  11  MagpieData minimum CovalentRadius     7262 non-null   float64
#  12  MagpieData maximum CovalentRadius     7262 non-null   float64
#  13  MagpieData range CovalentRadius       7262 non-null   float64
#  14  MagpieData mean CovalentRadius        7262 non-null   float64
#  15  MagpieData minimum Electronegativity  7262 non-null   float64
#  16  MagpieData maximum Electronegativity  7262 non-null   float64
#  17  MagpieData range Electronegativity    7262 non-null   float64
#  18  MagpieData mean Electronegativity     7262 non-null   float64
#  19  e_electronic                          7262 non-null   float64
#  20  e_ionic                               7262 non-null   float64
#  21  e_total                               7262 non-null   float64
# dtypes: float64(20), int64(2)
# memory usage: 1.2 MB

# %% [markdown]
# - Create X and y

# %%
X = data.drop(columns=['e_total', 'e_ionic', 'e_electronic'])
y = data['e_ionic']

# %% [markdown]
# - Train and test set split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

# %% [markdown]
# - Use StandScaler to scale X_train

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# scale x_test
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Linear regression model

# %%
def model_cross_train(model, X, y):
    '''Train the model model on X and return the results of cross-validation:
        1. scores（neg_root_mean_squared_error）
        2. y_hat'''
    kfold = KFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    scores = cross_val_score(model, X, y, scoring='neg_root_mean_squared_error', cv=kfold)
    y_hat = cross_val_predict(model, X, y, cv=kfold)
    return scores, y_hat

# After determining all the hyperparameters, train the model on the entire training set with the best hyperparameters
def model_final_train(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

def model_test(model, X_test, y_test):
    '''Test the model on the test set and return the results:
        1. mean_squared_error
        2. mean_absolute_error
        3. y_pred'''
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    return mse, mae, y_pred

# %% [markdown]
# ### Train the model

# %%
# draw parity plot
def parity_plot(mse, mae, y_test, y_pred, y_name="e_electronic", title='Parity Plot', fig_path=None, dpi=300):
    # draw parity plot
    fig, ax = plt.subplots(figsize=(8, 8), dpi=dpi)
    ax.scatter(y_test, y_pred, s=2, c="#9cc3e5", marker="^")
    ax.plot(y_test, y_test, c="#aad390", zorder=-5)
    ax.set_title(title)
    # relative dielectric constant, no unit
    ax.set_xlabel("Actual " + y_name)
    ax.set_ylabel("Predicted " + y_name)
    # ax.set_xscale("log")
    # ax.set_yscale("log")
    # make it diagonal distribution
    ax.set_aspect("equal", adjustable="box")
    # set the range of x and y to be the same
    ax.set_xlim([0, 50])
    ax.set_ylim([0, 50])
    # inward ticks
    ax.tick_params(axis='both', direction='in', length=4) 

    ax.grid(True, linestyle="--", alpha=0.4)
    
    # draw mse and mae on the plot of top_left
    # Add bbox to the plot
    bbox_props = dict(boxstyle="round,pad=0.8", ec="#aad390", lw=0.6, facecolor="white", alpha=0.6)
    ax.text(0.05, 0.95, "MSE: {:.2f}\n\nMAE: {:.2f}".format(mse, mae), transform=ax.transAxes, 
            fontsize=6, c='#9cc3e5', verticalalignment='top', bbox=bbox_props)

    plt.show()
    if fig_path:
        # Is there the directory of the fig_path
        if not os.path.exists(fig_path):
            os.makedirs(fig_path)
        fig.savefig(fig_path+title+".png", dpi=dpi, bbox_inches='tight')

# %%
# This model uses the analytical solution, so it does not include the setting of the learning rate
lr = LinearRegression()
scores, y_hat = model_cross_train(lr, X_train_scaled, y_train)

def plot_scores(mse, mae, y_train, y_hat, title='Parity Plot', fig_path=None, dpi=300):
    '''...'''
    print(f'MSE: {mse}, MAE: {mae}')

    # parity plot
    parity_plot(mse, mae, y_train, y_hat, y_name='e_ionic', title=title, fig_path=fig_path, dpi=dpi)


fig = plot_scores(-scores.mean()**2, 0, y_train, y_hat)
# Out:
# MSE: -1487.1004829818037, MAE: 0

# %%
lr.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Test：

# %%
mse, mae, y_pred = model_test(lr, X_test_scaled, y_test)
plot_scores(mse, mae, y_test, y_pred, title='Linear Regression', fig_path=FIG_PATH)
# Out:
# MSE: 2638.268293925076, MAE: 12.279050790758314

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree       # ML model

# decide the best depth of the decision tree
max_scores=-1e5
BEST_DEPTH=0
for depth in range(7, 19):
    dt = DecisionTreeRegressor(max_depth=depth,random_state=RANDOM_STATE)      # decision tree constructor
    scores, y_hat = model_cross_train(dt, X_train_scaled, y_train)     
    print(scores.mean(), depth)                         
    if scores.mean() > max_scores:
        max_scores = scores.mean()
        BEST_DEPTH = depth
        plot_scores(scores.mean()**2,0, y_train, y_hat)

print(f'Best depth: {BEST_DEPTH}')
# Out:
# -63.0557883433921 7
# MSE: 3976.0324436066635, MAE: 0
# -65.82510210174289 8
# -64.00229812521552 9
# -65.77404571408842 10
# -69.90844149027666 11
# -68.92717203608944 12
# -66.79744309198621 13
# -59.95062531016153 14
# MSE: 3594.07747507938, MAE: 0
# -61.962913775963216 15
# -68.20682301682561 16
# -65.21263647581111 17
# -71.86263456929586 18
# Best depth: 14

# %% [markdown]
# ### Model Train

# %%
dt = DecisionTreeRegressor(max_depth=BEST_DEPTH, random_state=RANDOM_STATE)
dt = model_final_train(dt, X_train_scaled, y_train)

# %% [markdown]
# ### Model Test

# %%
mse, mae, y_pred = model_test(dt, X_test_scaled, y_test)
plot_scores(mse, mae, y_test, y_pred, title='Decision Tree', fig_path=FIG_PATH)
# Out:
# MSE: 3111.7315474288976, MAE: 11.647456875162698

# %%
# feature importance
importance = dt.feature_importances_
importance = pd.DataFrame(importance, index=X.columns, columns=["Importance"])
importance = importance.sort_values(by="Importance", ascending=False)
importance.reset_index(inplace=True)
importance.columns = ['Feature', 'Importance']
importance
# Out:
#                                  Feature  Importance
# 0                                density    0.477548
# 1                            space_group    0.101949
# 2                                 volume    0.093869
# 3     MagpieData range Electronegativity    0.088827
# 4              formation_energy_per_atom    0.063739
# 5                         density_atomic    0.036422
# 6                MagpieData range Number    0.028941
# 7              MagpieData maximum Number    0.018839
# 8   MagpieData minimum Electronegativity    0.014193
# 9        MagpieData range CovalentRadius    0.013327
# 10        MagpieData mean CovalentRadius    0.013025
# 11     MagpieData mean Electronegativity    0.012024
# 12                MagpieData mean Number    0.010281
# 13                              band_gap    0.007854
# 14                        crystal_system    0.007420
# 15             MagpieData minimum Number    0.005463
# 16  MagpieData maximum Electronegativity    0.003251
# 17     MagpieData maximum CovalentRadius    0.001535
# 18     MagpieData minimum CovalentRadius    0.001491

# %%
list(importance['Feature'][:10])
# Out:
# ['density',
#  'space_group',
#  'volume',
#  'MagpieData range Electronegativity',
#  'formation_energy_per_atom',
#  'density_atomic',
#  'MagpieData range Number',
#  'MagpieData maximum Number',
#  'MagpieData minimum Electronegativity',
#  'MagpieData range CovalentRadius']

# %%
# Visualization of feature importance
import seaborn as sns

# 
fig = plt.figure(figsize=(10, 6), dpi=300)
sns.barplot(x='Importance', y='Feature', data=importance.iloc[:10], palette='GnBu_r', hue='Feature')
# show importance value
for i in range(10):
    plt.text(importance.iloc[i, 1], i, f'{importance.iloc[i, 1]:.3f}')
plt.xlabel('Importance', size=13)
plt.ylabel('Feature', size=13)
plt.title('Feature Importance of $\epsilon_{ionic}$', size=15)
plt.show()
# save the figure
fig.savefig(FIG_PATH+'feature_importance.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### Model Train

# %%
rf = RandomForestRegressor(n_estimators=100, max_depth=BEST_DEPTH, random_state=RANDOM_STATE)
rf = model_final_train(rf, X_train_scaled, y_train)

# %% [markdown]
# ### Model Test

# %%
mse, mae, y_pred = model_test(rf, X_test_scaled, y_test)
plot_scores(mse, mae, y_test, y_pred, title='Random Forest', fig_path=FIG_PATH)
# Out:
# MSE: 2744.293254110428, MAE: 11.208409151176628
