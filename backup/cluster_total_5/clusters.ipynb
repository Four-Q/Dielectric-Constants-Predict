# %% [markdown]
# # 通过聚类算法将总的数据划分成相似的几个组

# %% [markdown]
# ## 五个组

# %%
CLUSTER_NUMS = 5
RANDOM_STATE = 42

# %%
# 导库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# 导入数据
data = pd.read_csv('../../data/data_training.csv')

# %%
data.head()
# Out:
#   material_id    composition crystal_system  space_group  band_gap   density  \
# 0    mp-28967     Ba1 Pd2 S4     Monoclinic           11    0.7792  5.022717
# 1   mp-766094      Nb1 O2 F1   Orthorhombic           19    2.8980  3.764366
# 2    mp-36577     Sr1 As2 S4      Triclinic            1    1.7212  3.094976
# 3  mp-1102092  Na1 Fe1 S2 O8     Monoclinic           12    2.0944  2.901260
# 4   mp-720391    B1 H4 N1 F4   Orthorhombic           62    7.4812  1.860992
#
#    density_atomic  formation_energy_per_atom    e_total    e_ionic  ...  \
# 0       22.595815                  -1.124079  17.048334   7.118969  ...
# 1       15.869706                  -3.099174  17.572010  13.469477  ...
# 2       28.031499                  -0.766100  18.488667  12.443616  ...
# 3       12.923684                  -1.948264   9.596025   6.499905  ...
# 4        9.355010                  -1.970766   6.216546   4.350314  ...
#
#    MagpieData range Number  MagpieData mean Number  \
# 0                     40.0               30.285714
# 1                     33.0               16.500000
# 2                     22.0               24.000000
# 3                     18.0               11.083333
# 4                      8.0                5.200000
#
#    MagpieData minimum CovalentRadius  MagpieData maximum CovalentRadius  \
# 0                              105.0                              215.0
# 1                               57.0                              164.0
# 2                              105.0                              195.0
# 3                               66.0                              166.0
# 4                               31.0                               84.0
#
#    MagpieData range CovalentRadius  MagpieData mean CovalentRadius  \
# 0                            110.0                      130.428571
# 1                            107.0                       88.250000
# 2                             90.0                      121.857143
# 3                            100.0                       86.333333
# 4                             53.0                       50.700000
#
#    MagpieData minimum Electronegativity  MagpieData maximum Electronegativity  \
# 0                                  0.89                                  2.58
# 1                                  1.60                                  3.98
# 2                                  0.95                                  2.58
# 3                                  0.93                                  3.44
# 4                                  2.04                                  3.98
#
#    MagpieData range Electronegativity  MagpieData mean Electronegativity
# 0                                1.69                           2.230000
# 1                                2.38                           3.115000
# 2                                1.63                           2.232857
# 3                                2.51                           2.953333
# 4                                1.94                           2.980000
#
# [5 rows x 23 columns]

# %%
X = data.drop(columns=['material_id', 'composition', 'crystal_system'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7277 entries, 0 to 7276
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   space_group                           7277 non-null   int64
#  1   band_gap                              7277 non-null   float64
#  2   density                               7277 non-null   float64
#  3   density_atomic                        7277 non-null   float64
#  4   formation_energy_per_atom             7277 non-null   float64
#  5   e_total                               7277 non-null   float64
#  6   e_ionic                               7277 non-null   float64
#  7   e_electronic                          7277 non-null   float64
#  8   MagpieData minimum Number             7277 non-null   float64
#  9   MagpieData maximum Number             7277 non-null   float64
#  10  MagpieData range Number               7277 non-null   float64
#  11  MagpieData mean Number                7277 non-null   float64
#  12  MagpieData minimum CovalentRadius     7277 non-null   float64
#  13  MagpieData maximum CovalentRadius     7277 non-null   float64
#  14  MagpieData range CovalentRadius       7277 non-null   float64
#  15  MagpieData mean CovalentRadius        7277 non-null   float64
#  16  MagpieData minimum Electronegativity  7277 non-null   float64
#  17  MagpieData maximum Electronegativity  7277 non-null   float64
#  18  MagpieData range Electronegativity    7277 non-null   float64
#  19  MagpieData mean Electronegativity     7277 non-null   float64
# dtypes: float64(19), int64(1)
# memory usage: 1.1 MB

# %%
kmeans = KMeans(n_clusters=CLUSTER_NUMS, random_state=RANDOM_STATE)

# %%
kmeans.fit(X)
# Out:
# e:\software2\Anaconda\envs\pytorchEnv\lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=5, random_state=42)

# %%
X['cluster'] = kmeans.labels_

# %%
groups = X.groupby('cluster')

# %%
for cluster, df in groups:
    print(f'Cluster {cluster}: {len(df)} samples')
    display(df.head(5))
# Out:
# Cluster 0: 3384 samples
#     space_group  band_gap   density  density_atomic  \
# 9           173    1.4423  5.957552       25.814819
# 16          148    0.0000  5.698406       13.352739
# 17          152    4.0656  2.032981       27.083309
# 19          225    0.1981  6.182079       23.640230
# 21          139    4.3016  3.419061       15.236140
#
#     formation_energy_per_atom    e_total    e_ionic  e_electronic  \
# 9                   -1.615458  17.189158   8.379924      8.809235
# 16                  -2.310143   8.953313   5.759627      3.193686
# 17                  -0.268661   3.975662   1.825061      2.150601
# 19                  -1.093240  58.674453  23.928634     34.745818
# 21                  -2.856015   9.056451   6.910176      2.146275
#
#     MagpieData minimum Number  MagpieData maximum Number  ...  \
# 9                        14.0                       59.0  ...
# 16                        9.0                       80.0  ...
# 17                        6.0                       55.0  ...
# 19                       20.0                       79.0  ...
# 21                        9.0                       30.0  ...
#
#     MagpieData mean Number  MagpieData minimum CovalentRadius  \
# 9                39.666667                              111.0
# 16               19.750000                               57.0
# 17               14.666667                               71.0
# 19               38.000000                              119.0
# 21               14.857143                               57.0
#
#     MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 9                               203.0                             92.0
# 16                              139.0                             82.0
# 17                              244.0                            173.0
# 19                              176.0                             57.0
# 21                              203.0                            146.0
#
#     MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 9                       142.083333                                  1.13
# 16                       76.625000                                  1.66
# 17                      101.500000                                  0.79
# 19                      151.750000                                  1.00
# 21                      108.000000                                  0.82
#
#     MagpieData maximum Electronegativity  MagpieData range Electronegativity  \
# 9                                   2.55                                1.42
# 16                                  3.98                                2.32
# 17                                  3.04                                2.25
# 19                                  2.54                                1.54
# 21                                  3.98                                3.16
#
#     MagpieData mean Electronegativity  cluster
# 9                            2.089167        0
# 16                           3.442500        0
# 17                           2.501667        0
# 19                           1.680000        0
# 21                           2.744286        0
#
# [5 rows x 21 columns]
# Cluster 1: 1 samples
#       space_group  band_gap   density  density_atomic  \
# 5354          127    0.5537  4.401575         47.7105
#
#       formation_energy_per_atom        e_total        e_ionic  e_electronic  \
# 5354                   -1.20193  126575.316823  126567.273642      8.043181
#
#       MagpieData minimum Number  MagpieData maximum Number  ...  \
# 5354                       50.0                       55.0  ...
#
#       MagpieData mean Number  MagpieData minimum CovalentRadius  \
# 5354                    52.8                              139.0
#
#       MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 5354                              244.0                            105.0
#
#       MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 5354                           160.0                                  0.79
#
#       MagpieData maximum Electronegativity  \
# 5354                                  2.66
#
#       MagpieData range Electronegativity  MagpieData mean Electronegativity  \
# 5354                                1.87                              2.146
#
#       cluster
# 5354        1
#
# [1 rows x 21 columns]
# Cluster 2: 1 samples
#      space_group  band_gap   density  density_atomic  \
# 260          109       0.0  7.854668       17.740081
#
#      formation_energy_per_atom       e_total       e_ionic  e_electronic  \
# 260                  -0.670993  57262.630716  10404.720206   46857.91051
#
#      MagpieData minimum Number  MagpieData maximum Number  ...  \
# 260                       33.0                       41.0  ...
#
#      MagpieData mean Number  MagpieData minimum CovalentRadius  \
# 260                    37.0                              119.0
#
#      MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 260                              164.0                             45.0
#
#      MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 260                           141.5                                   1.6
#
#      MagpieData maximum Electronegativity  MagpieData range Electronegativity  \
# 260                                  2.18                                0.58
#
#      MagpieData mean Electronegativity  cluster
# 260                               1.89        2
#
# [1 rows x 21 columns]
# Cluster 3: 1 samples
#       space_group  band_gap   density  density_atomic  \
# 5112           12    1.1429  5.114826       30.542419
#
#       formation_energy_per_atom       e_total    e_ionic  e_electronic  \
# 5112                  -0.816408  25244.446111  95.629586  25148.816525
#
#       MagpieData minimum Number  MagpieData maximum Number  ...  \
# 5112                       34.0                       51.0  ...
#
#       MagpieData mean Number  MagpieData minimum CovalentRadius  \
# 5112                   40.25                              120.0
#
#       MagpieData maximum CovalentRadius  MagpieData range CovalentRadius  \
# 5112                              144.0                             24.0
#
#       MagpieData mean CovalentRadius  MagpieData minimum Electronegativity  \
# 5112                          127.75                                  1.69
#
#       MagpieData maximum Electronegativity  \
# 5112                                  2.96
#
#       MagpieData range Electronegativity  MagpieData mean Electronegativity  \
# 5112                                1.27                               2.42
#
#       cluster
# 5112        3
#
# [1 rows x 21 columns]
# Cluster 4: 3890 samples
#    space_group  band_gap   density  density_atomic  formation_energy_per_atom  \
# 0           11    0.7792  5.022717       22.595815                  -1.124079
# 1           19    2.8980  3.764366       15.869706                  -3.099174
# 2            1    1.7212  3.094976       28.031499                  -0.766100
# 3           12    2.0944  2.901260       12.923684                  -1.948264
# 4           62    7.4812  1.860992        9.355010                  -1.970766
#
#      e_total    e_ionic  e_electronic  MagpieData minimum Number  \
# 0  17.048334   7.118969      9.929365                       16.0
# 1  17.572010  13.469477      4.102533                        8.0
# 2  18.488667  12.443616      6.045051                       16.0
# 3   9.596025   6.499905      3.096120                        8.0
# 4   6.216546   4.350314      1.866232                        1.0
#
#    MagpieData maximum Number  ...  MagpieData mean Number  \
# 0                       56.0  ...               30.285714
# 1                       41.0  ...               16.500000
# 2                       38.0  ...               24.000000
# 3                       26.0  ...               11.083333
# 4                        9.0  ...                5.200000
#
#    MagpieData minimum CovalentRadius  MagpieData maximum CovalentRadius  \
# 0                              105.0                              215.0
# 1                               57.0                              164.0
# 2                              105.0                              195.0
# 3                               66.0                              166.0
# 4                               31.0                               84.0
#
#    MagpieData range CovalentRadius  MagpieData mean CovalentRadius  \
# 0                            110.0                      130.428571
# 1                            107.0                       88.250000
# 2                             90.0                      121.857143
# 3                            100.0                       86.333333
# 4                             53.0                       50.700000
#
#    MagpieData minimum Electronegativity  MagpieData maximum Electronegativity  \
# 0                                  0.89                                  2.58
# 1                                  1.60                                  3.98
# 2                                  0.95                                  2.58
# 3                                  0.93                                  3.44
# 4                                  2.04                                  3.98
#
#    MagpieData range Electronegativity  MagpieData mean Electronegativity  \
# 0                                1.69                           2.230000
# 1                                2.38                           3.115000
# 2                                1.63                           2.232857
# 3                                2.51                           2.953333
# 4                                1.94                           2.980000
#
#    cluster
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#
# [5 rows x 21 columns]

# %%
# 保存组0和组4的数据
for cluster, df in groups:
    if cluster in [0, 4]:
        df.to_csv(f'../../data/groups/data_training_cluster_{cluster}of{CLUSTER_NUMS}.csv', index=False)
